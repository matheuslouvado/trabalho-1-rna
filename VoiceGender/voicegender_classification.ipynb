# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('voice.csv')

# %%
df.head(2)
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
#
#          kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0  274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1  634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# 0  0.275862  0.007812  0.007812  0.007812  0.000000  0.000000   male
# 1  0.250000  0.009014  0.007812  0.054688  0.046875  0.052632   male
#
# [2 rows x 21 columns]

# %%
X = df.drop('label', axis=1)
y = df['label']
X.shape
# Out:
# (3168, 20)

# %%
df.describe()
# Out:
#           meanfreq           sd       median          Q25          Q75  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.180907     0.057126     0.185621     0.140456     0.224765
# std       0.029918     0.016652     0.036360     0.048680     0.023639
# min       0.039363     0.018363     0.010975     0.000229     0.042946
# 25%       0.163662     0.041954     0.169593     0.111087     0.208747
# 50%       0.184838     0.059155     0.190032     0.140286     0.225684
# 75%       0.199146     0.067020     0.210618     0.175939     0.243660
# max       0.251124     0.115273     0.261224     0.247347     0.273469
#
#                IQR         skew         kurt       sp.ent          sfm  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.084309     3.140168    36.568461     0.895127     0.408216
# std       0.042783     4.240529   134.928661     0.044980     0.177521
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
y_enc = le.fit_transform(y)

# %%
y_enc
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y_enc, test_size=0.33)

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model = keras.Sequential([ 
    keras.layers.Dense(7, input_shape=(20,), activation='relu', name='oculta1'),
    keras.layers.Dense(7, activation='relu', name='oculta2'),
    #keras.layers.Dense(7, activation='relu', name='oculta3'),
    keras.layers.Dense(1, activation='sigmoid', name='saida')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# oculta1 (Dense)              (None, 7)                 147
# _________________________________________________________________
# oculta2 (Dense)              (None, 7)                 56
# _________________________________________________________________
# saida (Dense)                (None, 1)                 8
# ...
# Total params: 211
# Trainable params: 211
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train,y_train, epochs = 200)
# Out:
# Train on 2122 samples
# Epoch 1/200
# 2122/2122 [==============================] - 2s 1ms/sample - loss: 1.1281 - accuracy: 0.5005
# Epoch 2/200
# 2122/2122 [==============================] - 1s 389us/sample - loss: 0.7090 - accuracy: 0.5198
# Epoch 3/200
# 2122/2122 [==============================] - 1s 429us/sample - loss: 0.6685 - accuracy: 0.6282
# Epoch 4/200
# 2122/2122 [==============================] - 1s 348us/sample - loss: 0.6613 - accuracy: 0.6418
# Epoch 5/200
# 2122/2122 [==============================] - 1s 428us/sample - loss: 0.6496 - accuracy: 0.6451
# Epoch 6/200
# 2122/2122 [==============================] - 1s 456us/sample - loss: 0.6417 - accuracy: 0.6527
# Epoch 7/200
# 2122/2122 [==============================] - 1s 532us/sample - loss: 0.6364 - accuracy: 0.6451
# Epoch 8/200
# 2122/2122 [==============================] - 1s 372us/sample - loss: 0.6313 - accuracy: 0.6499
# Epoch 9/200
# ...

# %%
model.evaluate(X_test,y_test)
# Out:
# 1046/1046 [==============================] - 1s 649us/sample - loss: 0.1375 - accuracy: 0.9465
# [0.13753467607338615, 0.9464627]
