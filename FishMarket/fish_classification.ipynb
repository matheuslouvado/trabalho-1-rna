# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Fish.csv')

# %%
df.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
X = df.drop('Species', axis=1)
y = df['Species']

# %%
X.shape
# Out:
# (159, 6)

# %%
y.unique()
# Out:
# array(['Bream', 'Roach', 'Whitefish', 'Parkki', 'Perch', 'Pike', 'Smelt'],
#       dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
y_enc = y.values.reshape(-1, 1)
one_hot = OneHotEncoder()
y_enc = one_hot.fit_transform(y_enc).toarray()

# %%
y_enc.shape
# Out:
# (159, 7)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y_enc, test_size=0.33)

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model = keras.Sequential([ 
    keras.layers.Dense(128, input_shape=(6,), activation='relu', name='oculta1'),
    keras.layers.Dense(64, activation='relu', name='oculta2'),
    keras.layers.Dense(32, activation='relu', name='oculta3'),
    keras.layers.Dense(7, activation='softmax', name='saida')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# oculta1 (Dense)              (None, 128)               896
# _________________________________________________________________
# oculta2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# oculta3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# saida (Dense)                (None, 7)                 231
# ...
# Total params: 11,463
# Trainable params: 11,463
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train,y_train, epochs = 200)
# Out:
# Train on 106 samples
# Epoch 1/200
# 106/106 [==============================] - 1s 13ms/sample - loss: 47.2589 - accuracy: 0.0472
# Epoch 2/200
# 106/106 [==============================] - 0s 615us/sample - loss: 26.8526 - accuracy: 0.1226
# Epoch 3/200
# 106/106 [==============================] - 0s 628us/sample - loss: 16.9766 - accuracy: 0.1509
# Epoch 4/200
# 106/106 [==============================] - 0s 668us/sample - loss: 9.7401 - accuracy: 0.1792
# Epoch 5/200
# 106/106 [==============================] - 0s 605us/sample - loss: 7.6048 - accuracy: 0.4340
# Epoch 6/200
# 106/106 [==============================] - 0s 751us/sample - loss: 5.0679 - accuracy: 0.2547
# Epoch 7/200
# 106/106 [==============================] - 0s 501us/sample - loss: 3.9329 - accuracy: 0.2358
# Epoch 8/200
# 106/106 [==============================] - 0s 497us/sample - loss: 2.5282 - accuracy: 0.3113
# Epoch 9/200
# ...

# %%
model.evaluate(X_test,y_test)
# Out:
# 53/53 [==============================] - 0s 9ms/sample - loss: 0.7619 - accuracy: 0.7925
# [0.7618813334770922, 0.7924528]
